# %% [markdown]
# # At-risk Students (Optional ML)
#
# This notebook demonstrates a simple approach to flag students as at-risk using attendance and marks features.

# %%
import pandas as pd
from pathlib import Path

curated = Path('..') / 'data' / 'curated'
print('Curated folder:', curated.resolve())
